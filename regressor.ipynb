# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/drive/My Drive/Flight_weather.csv")
df.dropna(how='any',inplace=True)
df
# Out:
#          Year  Quarter  Month  ...  winddirDegree humidity  airport
# 0        2016        1      1  ...            108       65      SEA
# 1        2016        1      1  ...            108       65      SEA
# 2        2016        1      1  ...            108       65      SEA
# 3        2016        1      1  ...            108       65      SEA
# 4        2016        1      1  ...            108       65      SEA
# ...       ...      ...    ...  ...            ...      ...      ...
# 1859971  2017        4     12  ...            123       88      EWR
# 1859972  2017        4     12  ...            219       90      ORD
# 1859973  2017        4     12  ...            219       90      ORD
# 1859974  2017        4     12  ...            177       89      SEA
# 1859975  2017        4     12  ...            113       78      IAH
#
# [1834170 rows x 28 columns]

# %%
import sklearn.preprocessing as preprocessing
le=preprocessing.LabelEncoder()
df["airport"]=le.fit_transform(df["airport"].astype(str))
df["FlightDate"]=le.fit_transform(df["FlightDate"].astype(str))
df
# Out:
#          Year  Quarter  Month  ...  winddirDegree  humidity  airport
# 0        2016        1      1  ...            108        65       13
# 1        2016        1      1  ...            108        65       13
# 2        2016        1      1  ...            108        65       13
# 3        2016        1      1  ...            108        65       13
# 4        2016        1      1  ...            108        65       13
# ...       ...      ...    ...  ...            ...       ...      ...
# 1859971  2017        4     12  ...            123        88        4
# 1859972  2017        4     12  ...            219        90       11
# 1859973  2017        4     12  ...            219        90       11
# 1859974  2017        4     12  ...            177        89       13
# 1859975  2017        4     12  ...            113        78        5
#
# [1834170 rows x 28 columns]

# %%
df=df[df['ArrDel15'] == 1.0]
df
# Out:
#          Year  Quarter  Month  ...  winddirDegree  humidity  airport
# 1        2016        1      1  ...            108        65       13
# 2        2016        1      1  ...            108        65       13
# 7        2016        1      1  ...            108        65       13
# 8        2016        1      1  ...            108        65       13
# 11       2016        1      1  ...            118        63       13
# ...       ...      ...    ...  ...            ...       ...      ...
# 1859936  2017        4     12  ...             78        90        5
# 1859948  2017        4     12  ...            124        84        5
# 1859965  2017        4     12  ...             77        77        5
# 1859973  2017        4     12  ...            219        90       11
# 1859974  2017        4     12  ...            177        89       13
#
# [383185 rows x 28 columns]

# %%
X=df.drop(["ArrDel15","ArrDelayMinutes"],axis=1)
y=df["ArrDelayMinutes"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#          Year  Quarter  Month  ...  winddirDegree  humidity  airport
# 1314952  2017        2      5  ...            266         6       12
# 1026054  2017        1      2  ...            297        58       10
# 1331026  2017        2      6  ...            256         7       12
# 165918   2016        1      3  ...            342        25        7
# 780222   2016        4     10  ...            187        79       11
# ...       ...      ...    ...  ...            ...       ...      ...
# 1704472  2017        4     10  ...            306        22       12
# 1695231  2017        4     10  ...             13        93        2
# 750571   2016        4     10  ...            108        30        5
# 578483   2016        3      8  ...            240        66        0
# 1429029  2017        3      7  ...            278        65       14
#
# [306548 rows x 26 columns]

# %%
from sklearn.linear_model import LinearRegression
lrmodel=LinearRegression()

# %%
lrmodel.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lrmodel.coef_
# Out:
# array([ 5.16111430e+00, -4.88356701e-01,  5.32240351e-01,  2.99764199e-03,
#        -1.26488148e-02,  1.05338218e-03, -2.36512951e+01, -2.61065896e-03,
#         9.74844670e-01,  8.88348178e-04,  5.30953260e-04,  3.62025569e-04,
#         7.07875020e-04,  5.52999866e-02,  4.30828900e-02,  9.37205903e-03,
#         1.08962950e-01, -1.05202384e-01, -1.42934770e-03, -1.11689350e-01,
#         1.11919096e-02,  1.77859489e-01, -1.77936868e-01, -8.05045214e-04,
#        -3.02727175e-02, -2.90959598e-01])

# %%
lrmodel.intercept_
# Out:
# -10291.908846254277

# %%
y_pred=lrmodel.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
print("rmse for linear regression is:",mean_squared_error(y_test,y_pred,squared=False))
print("MAE for linear regression is:",mean_absolute_error(y_test,y_pred))
print("R2_Score for linear regression is:",r2_score(y_test,y_pred))
# Out:
# rmse for linear regression is: 17.500333863879032
# MAE for linear regression is: 12.190583855030074
# R2_Score for linear regression is: 0.9384798783184184

# %%
from sklearn.ensemble import ExtraTreesRegressor
extra_tree_regressor = ExtraTreesRegressor()

# %%
extra_tree_regressor.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
y_pred_extratrees=extra_tree_regressor.predict(X_test)

# %%
print("rmse for extra trees regressor is:",mean_squared_error(y_test,y_pred_extratrees,squared=False))
print("MAE for extra trees regressor is:",mean_absolute_error(y_test,y_pred_extratrees))
print("R2_Score for extra trees regressor is:",r2_score(y_test,y_pred_extratrees))
# Out:
# rmse for extra trees regressor is: 12.99568667975661
# MAE for extra trees regressor is: 8.360989861294154
# R2_Score for extra trees regressor is: 0.9660747558372152

# %%
from sklearn.ensemble import RandomForestRegressor
Rf_regressor = RandomForestRegressor()

# %%
Rf_regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_RandomForest=Rf_regressor.predict(X_test)

# %%
print("rmse for random forest regressor is:",mean_squared_error(y_test,y_pred_RandomForest,squared=False))
print("MAE for random forest regressor is:",mean_absolute_error(y_test,y_pred_RandomForest))
print("R2_Score for random forest regressor is:",r2_score(y_test,y_pred_RandomForest))
# Out:
# rmse for random forest regressor is: 10.844003165788415
# MAE for random forest regressor is: 6.184523272048749
# R2_Score for random forest regressor is: 0.9763787003415457

# %%
from xgboost import XGBRegressor
Xgbregressor=XGBRegressor(objective="reg:linear")

# %%
Xgbregressor.fit(X_train,y_train)
# Out:
# [12:00:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
y_pred_Xg=Xgbregressor.predict(X_test)

# %%
print("rmse for Xgboost regressor is:",mean_squared_error(y_test,y_pred_Xg,squared=False))
print("MAE for Xgboost regressor is:",mean_absolute_error(y_test,y_pred_Xg))
print("R2_Score for Xgboost regressor is:",r2_score(y_test,y_pred_Xg))
# Out:
# rmse for Xgboost regressor is: 15.713142857751823
# MAE for Xgboost regressor is: 10.847144908141711
# R2_Score for Xgboost regressor is: 0.9504035449969281
